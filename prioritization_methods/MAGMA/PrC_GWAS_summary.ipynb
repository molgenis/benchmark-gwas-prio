# %%
import pandas as pd
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# ## Preparing the GWAS summary statistic of Prostate cancer to run in magma

# %%
df = pd.read_csv(r"C:\Users\Gebruiker\OneDrive\Documents\DSLS\integrated_omics\project\prostate_cancer\meta_v3_onco_euro_overall_ChrAll_1_release.txt", sep='\t', header=0)
# Out:
# C:\Users\Gebruiker\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(50)
# Out:
#                           MarkerName  \
# 0                       1_10177_A_AC
# 1                       1_10352_T_TA
# 2   1_10616_CCGCCGTTGCAAAGGCGCGCCG_C
# 3                        1_10642_G_A
# 4                        1_11008_C_G
# 5                        1_11012_C_G
# 6                        1_13110_G_A
# 7                        1_13116_T_G
# 8                        1_13118_A_G
# 9                        1_13273_G_C
# 10                       1_13289_C_T
# 11                       1_13494_A_G
# 12                       1_13543_T_G
# 13                       1_13550_G_A
# 14                       1_14464_A_T
# 15                       1_14599_T_A
# 16                       1_14604_A_G
# 17                       1_14728_C_A
# 18                       1_14930_A_G
# 19                       1_14933_G_A
# 20                       1_14975_C_T
# 21                       1_15211_T_G
# 22                       1_15274_A_G
# 23                       1_15274_A_T
# ...

# %%
df = df.dropna()

# %%
#df[df['SNP'].str[0].isin(['rs'])]
# Out:
# Empty DataFrame
# Columns: [MarkerName, rs_id, SNP, Chr, position, Allele1, Allele2, Freq1, FreqSE, MinFreq, MaxFreq, Effect, StdErr, Pvalue, Direction, OncoArray_imputation_r2]
# Index: []

# %%
#data = df[df.SNP.str.startswith('rs')]

# %%
data = df[df.SNP.str.startswith("rs")].loc[:,["SNP", "Chr", 
                                             "position", "Pvalue"]]

# %%
data
# Out:
#                   SNP  Chr   position   Pvalue
# 1         rs145072688    1      10352  0.46280
# 2         rs376342519    1      10616  0.41070
# 7         rs201725126    1      13116  0.84470
# 8         rs200579949    1      13118  0.84470
# 18         rs75454623    1      14930  0.61880
# ...               ...  ...        ...      ...
# 20261673  rs111639741   23  129062079  0.51050
# 20261675  rs371460327   23  129062459  0.01093
# 20261676  rs151204157   23  129062460  0.33980
# 20261679  rs187453998   23  129063265  0.28060
# 20261680  rs111975985   23  129063293  0.47570
#
# [13498991 rows x 4 columns]

# %%
data = data.rename(columns= {'Chr':'CHR', 'position':'POS', 'Pvalue':'P'})

# %%
data
# Out:
#                   SNP  CHR        POS        P
# 1         rs145072688    1      10352  0.46280
# 2         rs376342519    1      10616  0.41070
# 7         rs201725126    1      13116  0.84470
# 8         rs200579949    1      13118  0.84470
# 18         rs75454623    1      14930  0.61880
# ...               ...  ...        ...      ...
# 20261673  rs111639741   23  129062079  0.51050
# 20261675  rs371460327   23  129062459  0.01093
# 20261676  rs151204157   23  129062460  0.33980
# 20261679  rs187453998   23  129063265  0.28060
# 20261680  rs111975985   23  129063293  0.47570
#
# [13498991 rows x 4 columns]

# %%
out_file = Path("C:\\Users\\Gebruiker\\OneDrive\\Documents\\DSLS\\integrated_omics\\project\\prostate_cancer") / "magma_step2_prstcan.txt"

data.to_csv(out_file, sep="\t", index = False)
