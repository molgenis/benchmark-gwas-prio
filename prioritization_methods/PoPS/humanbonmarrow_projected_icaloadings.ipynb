# %%
import pandas as pd
import os
from pathlib import Path

file = "C:\\Users\\Gebruiker\\OneDrive\\Documents\\DSLS\\integrated_omics\\project\\POPS\\step0\\features_row_hbn\\hbn_projected_icaloadings.txt"

data = pd.read_csv(file, sep='\t', header=0)

# %%
os.path.basename(file)
# Out:
# 'hbn_projected_icaloadings.txt'

# %%
file_name = Path(file).stem
file_name
# Out:
# 'hbn_projected_icaloadings'

# %%
new_cols = [file_name + "." + column for column in data.columns[1:].values]
new_cols.insert(0, data.columns[0])

# %%
new_cols
# Out:
# ['ENSG',
#  'hbn_projected_icaloadings.IC_1',
#  'hbn_projected_icaloadings.IC_2',
#  'hbn_projected_icaloadings.IC_3',
#  'hbn_projected_icaloadings.IC_4',
#  'hbn_projected_icaloadings.IC_5',
#  'hbn_projected_icaloadings.IC_6',
#  'hbn_projected_icaloadings.IC_7',
#  'hbn_projected_icaloadings.IC_8',
#  'hbn_projected_icaloadings.IC_9',
#  'hbn_projected_icaloadings.IC_10',
#  'hbn_projected_icaloadings.IC_11',
#  'hbn_projected_icaloadings.IC_12',
#  'hbn_projected_icaloadings.IC_13',
#  'hbn_projected_icaloadings.IC_14',
#  'hbn_projected_icaloadings.IC_15',
#  'hbn_projected_icaloadings.IC_16',
#  'hbn_projected_icaloadings.IC_17',
#  'hbn_projected_icaloadings.IC_18',
#  'hbn_projected_icaloadings.IC_19',
#  'hbn_projected_icaloadings.IC_20',
#  'hbn_projected_icaloadings.IC_21',
#  'hbn_projected_icaloadings.IC_22',
#  'hbn_projected_icaloadings.IC_23',
#  'hbn_projected_icaloadings.IC_24',
#  'hbn_projected_icaloadings.IC_25',
#  'hbn_projected_icaloadings.IC_26',
#  'hbn_projected_icaloadings.IC_27',
#  'hbn_projected_icaloadings.IC_28',
#  'hbn_projected_icaloadings.IC_29',
#  'hbn_projected_icaloadings.IC_30']

# %%
data.columns = new_cols
data
# Out:
#                   ENSG  hbn_projected_icaloadings.IC_1  \
# 0      ENSG00000186092                      978.241840
# 1      ENSG00000235249                      978.241840
# 2      ENSG00000185097                      978.241840
# 3      ENSG00000187634                      881.629202
# 4      ENSG00000188976                     3213.078847
# ...                ...                             ...
# 18378  ENSG00000165724                     2365.117237
# 18379  ENSG00000197070                    -6167.786121
# 18380  ENSG00000203993                     2543.190335
# 18381  ENSG00000181090                     2034.406641
# 18382  ENSG00000148408                      979.667144
#
#        hbn_projected_icaloadings.IC_2  hbn_projected_icaloadings.IC_3  \
# 0                        -1274.153824                    -1002.631426
# 1                        -1274.153824                    -1002.631426
# 2                        -1274.153824                    -1002.631426
# 3                        -1115.649903                     -953.633033
# 4                          287.305045                     3556.684963
# ...                               ...                             ...
# 18378                    -1482.667159                    -1162.351137
# 18379                     5158.430042                     6642.279863
# 18380                    -1792.336028                    -2483.489949
# 18381                     2052.698153                     1998.364019
# 18382                    -1275.088496                    -1006.890676
#
#        hbn_projected_icaloadings.IC_4  hbn_projected_icaloadings.IC_5  \
# 0                          159.610232                      -54.222235
# 1                          159.610232                      -54.222235
# 2                          159.610232                      -54.222235
# 3                          244.969494                       22.648973
# 4                         1440.202855                    -3367.606832
# ...                               ...                             ...
# 18378                      719.047145                    -1023.961045
# 18379                     2403.043448                    -1746.782967
# 18380                      696.110686                      331.088223
# 18381                     2205.749995                      755.884780
# 18382                      161.000374                      -54.893206
#
#        hbn_projected_icaloadings.IC_6  hbn_projected_icaloadings.IC_7  \
# 0                         1032.255393                     2496.109338
# 1                         1032.255393                     2496.109338
# 2                         1032.255393                     2496.109338
# 3                         1020.987083                     2629.962774
# 4                        -3638.433664                    -5474.071660
# ...                               ...                             ...
# 18378                      592.501611                     3448.655057
# 18379                      389.655025                    -2078.112553
# 18380                     -660.592853                        9.280467
# 18381                    -1967.707323                    -3120.485740
# 18382                     1036.990986                     2488.343768
#
#        hbn_projected_icaloadings.IC_8  hbn_projected_icaloadings.IC_9  ...  \
# 0                         -763.808728                     -965.577193  ...
# 1                         -763.808728                     -965.577193  ...
# 2                         -763.808728                     -965.577193  ...
# 3                         -768.263992                    -1113.640740  ...
# 4                         1895.737769                     1372.566146  ...
# ...                               ...                             ...  ...
# 18378                     4588.790947                     -363.748165  ...
# 18379                    -2509.345749                     1609.656548  ...
# 18380                    -1010.751936                      784.354380  ...
# 18381                     1793.167361                     2216.901479  ...
# 18382                     -762.233031                     -960.738672  ...
#
#        hbn_projected_icaloadings.IC_21  hbn_projected_icaloadings.IC_22  \
# 0                          -457.877360                       252.607100
# 1                          -457.877360                       252.607100
# 2                          -457.877360                       252.607100
# 3                          -665.300233                       200.190367
# 4                         -1610.246710                       427.774624
# ...                                ...                              ...
# 18378                      2470.804500                       103.601388
# 18379                     -1212.291113                       224.479567
# 18380                       590.203673                       640.392822
# 18381                      1227.708172                     -1876.855981
# 18382                      -459.369085                       243.653596
#
#        hbn_projected_icaloadings.IC_23  hbn_projected_icaloadings.IC_24  \
# 0                           719.570960                      -432.032825
# 1                           719.570960                      -432.032825
# 2                           719.570960                      -432.032825
# 3                           914.328662                      -425.099229
# 4                          -201.890134                      -127.859345
# ...                                ...                              ...
# 18378                     -1798.772471                      -131.322791
# 18379                      1193.294948                      1265.760395
# 18380                      -764.781146                      -136.382896
# 18381                      -879.199631                      2061.630129
# 18382                       719.846479                      -449.369724
#
#        hbn_projected_icaloadings.IC_25  hbn_projected_icaloadings.IC_26  \
# 0                            41.487516                       184.602711
# 1                            41.487516                       184.602711
# 2                            41.487516                       184.602711
# 3                           -28.828379                         4.117196
# 4                           230.442165                      1289.256433
# ...                                ...                              ...
# 18378                      1470.899380                      -566.448447
# 18379                       681.331101                       277.550762
# 18380                       663.668299                      1002.787844
# 18381                      -276.770210                     -1942.448717
# 18382                        48.990927                       183.654283
#
#        hbn_projected_icaloadings.IC_27  hbn_projected_icaloadings.IC_28  \
# 0                             2.673172                      -400.418854
# 1                             2.673172                      -400.418854
# 2                             2.673172                      -400.418854
# 3                           143.010907                      -388.294808
# 4                          1407.608700                     -1675.422343
# ...                                ...                              ...
# 18378                       371.122936                      -630.330507
# 18379                      2204.819622                        59.572557
# 18380                       708.339175                      -460.985740
# 18381                       330.132205                      -355.302688
# 18382                        10.443154                      -387.644190
#
#        hbn_projected_icaloadings.IC_29  hbn_projected_icaloadings.IC_30
# 0                          -127.629702                       119.470569
# 1                          -127.629702                       119.470569
# 2                          -127.629702                       119.470569
# 3                          -137.093239                        -4.018534
# 4                          -401.073089                      -569.206879
# ...                                ...                              ...
# 18378                      -438.764563                      1182.803919
# 18379                      -338.648517                       -99.808814
# 18380                      -291.317922                       274.024925
# 18381                      -589.170966                       432.336492
# 18382                      -132.961701                       123.968380
#
# [18383 rows x 31 columns]

# %%
out_file = Path("C:\\Users\\Gebruiker\\OneDrive\\Documents\\DSLS\\integrated_omics\\project\\POPS") / "hbn_projected_icaloadings.txt"

data.to_csv(out_file, sep="\t", index = False)
