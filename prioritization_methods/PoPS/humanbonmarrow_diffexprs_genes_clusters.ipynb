# %%
import pandas as pd
import os
from pathlib import Path

file = 'C:\\Users\\Gebruiker\\OneDrive\\Documents\\DSLS\\integrated_omics\\project\\POPS\\step0\\features_row_hbn\\hbn_diffexprs_genes_clusters.txt'

data = pd.read_csv(file, sep='\t', header=0)

# %%
os.path.basename(file)
# Out:
# 'hbn_diffexprs_genes_clusters.txt'

# %%
file_name = Path(file).stem
file_name
# Out:
# 'hbn_diffexprs_genes_clusters'

# %%
new_cols = [file_name + "." + column for column in data.columns[1:].values]
new_cols.insert(0, data.columns[0])

# %%
new_cols
# Out:
# ['ENSG',
#  'hbn_diffexprs_genes_clusters.Cluster2',
#  'hbn_diffexprs_genes_clusters.Cluster6',
#  'hbn_diffexprs_genes_clusters.Cluster3',
#  'hbn_diffexprs_genes_clusters.Cluster11',
#  'hbn_diffexprs_genes_clusters.Cluster5',
#  'hbn_diffexprs_genes_clusters.Cluster7',
#  'hbn_diffexprs_genes_clusters.Cluster4',
#  'hbn_diffexprs_genes_clusters.Cluster9',
#  'hbn_diffexprs_genes_clusters.Cluster13',
#  'hbn_diffexprs_genes_clusters.Cluster12',
#  'hbn_diffexprs_genes_clusters.Cluster10',
#  'hbn_diffexprs_genes_clusters.Cluster8',
#  'hbn_diffexprs_genes_clusters.Cluster1',
#  'hbn_diffexprs_genes_clusters.Cluster14',
#  'hbn_diffexprs_genes_clusters.Cluster15']

# %%
data.columns = new_cols
data
# Out:
#                   ENSG  hbn_diffexprs_genes_clusters.Cluster2  \
# 0      ENSG00000186092                                      0
# 1      ENSG00000235249                                      0
# 2      ENSG00000185097                                      0
# 3      ENSG00000187634                                      0
# 4      ENSG00000188976                                      1
# ...                ...                                    ...
# 18378  ENSG00000165724                                      0
# 18379  ENSG00000197070                                      1
# 18380  ENSG00000203993                                      0
# 18381  ENSG00000181090                                      1
# 18382  ENSG00000148408                                      0
#
#        hbn_diffexprs_genes_clusters.Cluster6  \
# 0                                          0
# 1                                          0
# 2                                          0
# ...

# %%
out_file = Path("C:\\Users\\Gebruiker\\OneDrive\\Documents\\DSLS\\integrated_omics\\project\\POPS") / "hbn_diffexprs_genes_clusters.txt"

data.to_csv(out_file, sep="\t", index = False)
