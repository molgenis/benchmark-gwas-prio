# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
# Out:
# C:\Users\Gebruiker\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Gebruiker\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\Gebruiker\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ## combining the raw features of colone and humanbonmarrow to run with Height GWAS summary statistics

# %%
arr = os.listdir('combine')

out_dir = Path("combine")

for file in arr:
    new_name = prefix + file
    # First rename the files
    os.rename(out_dir / file, out_dir / new_name)
    
    # Read in the data
    df = pd.read_csv(out_dir / new_name, sep="\t", header=0)
    
    # Get the name without extension
    base_name = Path(out_dir / new_name).stem
    print(base_name)
    # Add the file name to the columns
    new_cols = [base_name + "." + column for column in df.columns[1:].values]
    df.columns.values[1:] = new_cols
    
    # Overwrite the existing files with the new data frame
    df.to_csv(out_dir / new_name, sep="\t", index=False, mode="w+")
    
df
# Out:
# height_colon_average_expression
# height_colon_average_expression_pre_def
# height_colon_diffexprs_down_genes_clusters_pre_def
# height_colon_diffexprs_genes_clusters
# height_colon_diffexprs_genes_clusters_pre_def
# height_colon_diffexprs_tstat_clusters
# height_colon_diffexprs_tstat_clusters_pre_def
# height_colon_projected_icaloadings
# height_colon_projected_pcaloadings
# height_colon_projected_pcaloadings_clusters
# height_colon_projected_pcaloadings_clusters_pre_def
# height_hbn_average_expression
# height_hbn_diffexprs_down_genes_clusters
# height_hbn_diffexprs_genes_clusters
# height_hbn_diffexprs_tstat_clusters
# height_hbn_projected_icaloadings
# height_hbn_projected_pcaloadings
# height_hbn_projected_pcaloadings_clusters
#                   ENSG  \
# 0      ENSG00000186092
# 1      ENSG00000235249
# 2      ENSG00000185097
# 3      ENSG00000187634
# 4      ENSG00000188976
# ...                ...
# 18378  ENSG00000165724
# 18379  ENSG00000197070
# 18380  ENSG00000203993
# 18381  ENSG00000181090
# 18382  ENSG00000148408
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_1  \
# 0                                            2654.073410
# 1                                            2654.073410
# 2                                            2654.073410
# 3                                             475.500107
# 4                                            8438.171169
# ...                                                  ...
# 18378                                       -9975.882778
# 18379                                       -7204.112911
# 18380                                        4948.491193
# 18381                                       -6262.134940
# 18382                                        2202.745586
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_2  \
# 0                                             -29.081648
# 1                                             -29.081648
# 2                                             -29.081648
# 3                                             121.065328
# 4                                            -544.836213
# ...                                                  ...
# 18378                                         429.975392
# 18379                                         444.086591
# 18380                                          26.176414
# 18381                                       -1463.645980
# 18382                                           6.545133
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_3  \
# 0                                              36.395993
# 1                                              36.395993
# 2                                              36.395993
# 3                                             -81.450564
# 4                                              84.635517
# ...                                                  ...
# 18378                                         147.038640
# 18379                                         -75.043388
# 18380                                          57.802057
# 18381                                          47.612655
# 18382                                          32.072936
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_4  \
# 0                                            -167.206122
# 1                                            -167.206122
# 2                                            -167.206122
# 3                                            -324.675005
# 4                                            -293.919982
# ...                                                  ...
# 18378                                        -119.411243
# 18379                                          63.311053
# 18380                                        -895.741541
# 18381                                         582.155792
# 18382                                        -169.539399
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_5  \
# 0                                              -9.529354
# 1                                              -9.529354
# 2                                              -9.529354
# 3                                              23.200573
# 4                                             456.689616
# ...                                                  ...
# 18378                                         164.321300
# 18379                                        -152.823979
# 18380                                         557.486681
# 18381                                         -57.855878
# 18382                                         -15.785300
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_6  \
# 0                                              14.059375
# 1                                              14.059375
# 2                                              14.059375
# 3                                             -13.507023
# 4                                           -1017.270217
# ...                                                  ...
# 18378                                         127.006235
# 18379                                        -340.910231
# 18380                                         234.156165
# 18381                                         179.794074
# 18382                                          16.156492
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_7  \
# 0                                              44.916569
# 1                                              44.916569
# 2                                              44.916569
# 3                                             -32.413529
# 4                                              -3.233065
# ...                                                  ...
# 18378                                        -133.935104
# 18379                                         588.698551
# 18380                                        -198.860222
# 18381                                        -278.633843
# 18382                                          43.269547
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_8  \
# 0                                              39.760979
# 1                                              39.760979
# 2                                              39.760979
# 3                                              24.604738
# 4                                            -559.512163
# ...                                                  ...
# 18378                                        -288.911412
# 18379                                        -489.202772
# 18380                                         -41.879201
# 18381                                          33.442144
# 18382                                          44.220118
#
#        height_hbn_projected_pcaloadings_clusters.Cluster0_PC_9  ...  \
# 0                                             -57.726365        ...
# 1                                             -57.726365        ...
# 2                                             -57.726365        ...
# 3                                              81.694864        ...
# 4                                            -345.171656        ...
# ...                                                  ...        ...
# 18378                                        -256.138799        ...
# 18379                                          23.899356        ...
# 18380                                        -102.646096        ...
# 18381                                        -169.262689        ...
# 18382                                         -59.470429        ...
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_1  \
# 0                                             -50.528569
# 1                                             -50.528569
# 2                                             -50.528569
# 3                                             -97.094769
# 4                                            -282.168939
# ...                                                  ...
# 18378                                         -88.031948
# 18379                                        -793.215406
# 18380                                         118.864881
# 18381                                        -539.808282
# 18382                                         -59.503622
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_2  \
# 0                                             -27.073112
# 1                                             -27.073112
# 2                                             -27.073112
# 3                                               4.181159
# 4                                             -79.992981
# ...                                                  ...
# 18378                                         230.295334
# 18379                                          49.469438
# 18380                                          -7.049043
# 18381                                         -30.200293
# 18382                                         -23.529445
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_3  \
# 0                                              -9.788416
# 1                                              -9.788416
# 2                                              -9.788416
# 3                                              -3.697097
# 4                                             -15.361909
# ...                                                  ...
# 18378                                         -31.771460
# 18379                                          23.254264
# 18380                                         -26.579549
# 18381                                         -14.801546
# 18382                                          -9.897016
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_4  \
# 0                                              -1.050058
# 1                                              -1.050058
# 2                                              -1.050058
# 3                                               2.709400
# 4                                              33.242824
# ...                                                  ...
# 18378                                          44.313939
# 18379                                         162.912910
# 18380                                          45.940316
# 18381                                           3.719951
# 18382                                          -0.365836
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_5  \
# 0                                               9.388476
# 1                                               9.388476
# 2                                               9.388476
# 3                                              11.743815
# 4                                             -79.142195
# ...                                                  ...
# 18378                                          -4.172350
# 18379                                         -32.047464
# 18380                                         -40.314981
# 18381                                          75.547599
# 18382                                           8.896050
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_6  \
# 0                                              -9.852579
# 1                                              -9.852579
# 2                                              -9.852579
# 3                                              -0.249731
# 4                                              64.743380
# ...                                                  ...
# 18378                                         -12.907291
# 18379                                          35.950420
# 18380                                        -112.621044
# 18381                                         -29.547067
# 18382                                          -9.873236
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_7  \
# 0                                               5.823463
# 1                                               5.823463
# 2                                               5.823463
# 3                                               3.968714
# 4                                            -125.344279
# ...                                                  ...
# 18378                                           2.370414
# 18379                                          65.767088
# 18380                                          32.112739
# 18381                                          63.538586
# 18382                                           5.701263
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_8  \
# 0                                               0.705437
# 1                                               0.705437
# 2                                               0.705437
# 3                                              -1.727317
# 4                                             -62.237411
# ...                                                  ...
# 18378                                          41.223615
# 18379                                         -71.624377
# 18380                                          60.696000
# 18381                                          50.691938
# 18382                                           0.921043
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_9  \
# 0                                              -1.720061
# 1                                              -1.720061
# 2                                              -1.720061
# 3                                               3.391924
# 4                                             -88.151182
# ...                                                  ...
# 18378                                         -42.526573
# 18379                                           3.800711
# 18380                                          38.971336
# 18381                                         -77.837784
# 18382                                          -1.772999
#
#        height_hbn_projected_pcaloadings_clusters.Cluster14_PC_10
# 0                                               1.090288
# 1                                               1.090288
# 2                                               1.090288
# 3                                               3.091096
# 4                                             -87.553917
# ...                                                  ...
# 18378                                         -46.036795
# 18379                                        -107.703665
# 18380                                           0.351803
# 18381                                        -127.222963
# 18382                                           0.921015
#
# [18383 rows x 151 columns]
